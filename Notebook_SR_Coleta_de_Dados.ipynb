# %% [markdown]
# ## Etapa 2 - Coleta dos Dados
#
# Nesse notebook realizamos as requisições da API TMDB para buscar os filmes já produzidos. Ao final exportamos um dataframe gerado em um arquivi CSV, para serem utilizados nas etapas seguintes do projeto.

# %% [markdown]
# ### Instalçao de Bibliotecas

# %%
# !pip install tmdbv3api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tmdbv3api in /usr/local/lib/python3.7/dist-packages (1.7.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from tmdbv3api) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->tmdbv3api) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->tmdbv3api) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->tmdbv3api) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->tmdbv3api) (3.0.4)

# %% [markdown]
# ###Importando Bibliotecas

# %%
#Tratamento de dados
import pandas as pd

#Requisição de dados na API
import requests

#Tratamento Json
import json 

#Biblioteca tmdb 
from tmdbv3api import Movie, TMDb

# %%
tmdb = TMDb()
tmdb.api_key = "c6873695bc040a9de0b1ede3f6b1af13"

# %%
tmdb_movie = Movie()

# %%
df = pd.read_csv("movies_metadata.csv")
df.head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ```
# # Isto` está formatado como código`
# ```
#
# ### Filmes de 2018

# %%
url = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"

df1 = pd.read_html(url, header = 0)[2]
df2 = pd.read_html(url, header = 0)[3]
df3 = pd.read_html(url, header = 0)[4]
df4 = pd.read_html(url, header = 0)[5]

df4.tail(5)
# Out:
#      Opening  Opening.1                       Title  \
# 61  DECEMBER         25             Holmes & Watson
# 62  DECEMBER         25                        Vice
# 63  DECEMBER         25         On the Basis of Sex
# 64  DECEMBER         25                   Destroyer
# 65  DECEMBER         28  Black Mirror: Bandersnatch
#
#                               Production company  \
# 61  Columbia Pictures / Gary Sanchez Productions
# 62     Annapurna Pictures / Plan B Entertainment
# 63                                Focus Features
# 64                            Annapurna Pictures
# 65                                       Netflix
#
#                                         Cast and crew   Ref.
# 61  Etan Cohen (director/screenplay); Will Ferrell...  [164]
# 62  Adam McKay (director/screenplay); Christian Ba...  [137]
# 63  Mimi Leder (director); Daniel Stiepleman (scre...  [228]
# 64  Karyn Kusama (director); Phil Hay, Matt Manfre...  [260]
# 65  David Slade (director); Charlie Brooker (scree...  [261]

# %%
df_2018 = df1.append(df2.append(df3.append(df4, ignore_index=True), ignore_index=True), ignore_index=True)
df_2018.tail(6)
# Out:
#       Opening  Opening.1                       Title  \
# 266  DECEMBER         21                    Cold War
# 267  DECEMBER         25             Holmes & Watson
# 268  DECEMBER         25                        Vice
# 269  DECEMBER         25         On the Basis of Sex
# 270  DECEMBER         25                   Destroyer
# 271  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                Production company  \
# 266                                Amazon Studios
# 267  Columbia Pictures / Gary Sanchez Productions
# 268     Annapurna Pictures / Plan B Entertainment
# 269                                Focus Features
# 270                            Annapurna Pictures
# 271                                       Netflix
#
#                                          Cast and crew  \
# 266  Paweł Pawlikowski (director); Paweł Pawlikowsk...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271  David Slade (director); Charlie Brooker (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
#
#       Ref.
# 266  [259]
# 267  [164]
# 268  [137]
# 269  [228]
# 270  [260]
# 271  [261]

# %%
df_2018 = df_2018.filter(["Title", "Opening"], axis = 1)

df_2018.head()
# Out:
#                      Title  Opening
# 0  Insidious: The Last Key  JANUARY
# 1         The Strange Ones  JANUARY
# 2                 Stratton  JANUARY
# 3            Sweet Country  JANUARY
# 4             The Commuter  JANUARY

# %%
df_2018.shape
# Out:
# (272, 2)

# %%
def get_id_movie_2018 (title_movie):
  result = tmdb_movie.search(title_movie)
  try:
   movie_id = result[0].id
  except:
   movie_id = -1 
  return movie_id

# %%
df_2018["id"] = df_2018["Title"].map(lambda x : get_id_movie_2018(str(x)))

# %%
df_2018.head()
# Out:
#                      Title  Opening      id
# 0  Insidious: The Last Key  JANUARY  406563
# 1         The Strange Ones  JANUARY  426258
# 2                 Stratton  JANUARY  348389
# 3            Sweet Country  JANUARY  468210
# 4             The Commuter  JANUARY  399035

# %%
df_2018.drop(columns =["Opening"], inplace =True)

# %%
df_2018.rename(columns ={"Title" : "Original_title"}, inplace = True)

df_2018.head()
# Out:
#             Original_title      id
# 0  Insidious: The Last Key  406563
# 1         The Strange Ones  426258
# 2                 Stratton  348389
# 3            Sweet Country  468210
# 4             The Commuter  399035

# %% [markdown]
# ### Filmes de 2019

# %%
url_2019= "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"

# %%
df1_2019 = pd.read_html(url_2019, header = 0)[2]
df2_2019 = pd.read_html(url_2019, header = 0)[3]
df3_2019 = pd.read_html(url_2019, header = 0)[4]
df4_2019 = pd.read_html(url_2019, header = 0)[5]

# %%
df4_2019.head()
# Out:
#    Opening  Opening.1                Title  \
# 0  OCTOBER          4                Joker
# 1  OCTOBER          4      Lucy in the Sky
# 2  OCTOBER          4  Dolemite Is My Name
# 3  OCTOBER          4    In the Tall Grass
# 4  OCTOBER          4             Low Tide
#
#                                   Production company  \
# 0  Warner Bros. Pictures / Village Roadshow Pictu...
# 1                           Fox Searchlight Pictures
# 2                                            Netflix
# 3                                            Netflix
# 4                               A24 / DirecTV Cinema
#
#                                        Cast and crew   Ref.
# 0  Todd Phillips (director/screenplay); Scott Sil...  [168]
# 1  Noah Hawley (director/screenplay); Brian C. Br...  [169]
# 2  Craig Brewer (director); Scott Alexander and L...  [165]
# 3  Vincenzo Natali (director/screenplay); Patrick...    NaN
# 4  Kevin McMullin (director/screenplay); Keean Jo...  [170]

# %%
df_2019 = df1_2019.append(df2_2019.append(df3_2019.append(df4_2019, ignore_index=True), ignore_index=True), ignore_index=True)
df_2019.head(6)
# Out:
#    Opening  Opening.1             Title                 Production company  \
# 0  JANUARY          4       Escape Room  Columbia Pictures / Original Film
# 1  JANUARY          4        Rust Creek                          IFC Films
# 2  JANUARY          4  American Hangman        Hangman Justice Productions
# 3  JANUARY         11  A Dog's Way Home                  Columbia Pictures
# 4  JANUARY         11        The Upside                  STX Entertainment
# 5  JANUARY         11          Replicas              Entertainment Studios
#
#                                        Cast and crew Ref.
# 0  Adam Robitel (director); Bragi F. Schut, Maria...  [2]
# 1  Jen McGowan (director); Julie Lipson (screenpl...  [3]
# 2  Wilson Coneybeare (director/screenplay); Donal...  [4]
# 3  Charles Martin Smith (director); W. Bruce Came...  [5]
# 4  Neil Burger (director); Jon Hartmere (screenpl...  [6]
# 5  Jeffrey Nachmanoff (director); Chad St. John (...  [7]

# %%
df_2019 = df_2019.filter(["Title", "Opening"], axis = 1)
df_2019.shape
# Out:
# (243, 2)

# %%
def get_id_movie_2019 (title_movie):
  result = tmdb_movie.search(title_movie)
  try:
   movie_id = result[0].id
  except:
   movie_id = -1 
  return movie_id

# %%
df_2019["id"] = df_2019["Title"].map(lambda x : get_id_movie_2019(str(x)))

df_2019.head()
# Out:
#               Title  Opening      id
# 0       Escape Room  JANUARY  522681
# 1        Rust Creek  JANUARY  561362
# 2  American Hangman  JANUARY  567738
# 3  A Dog's Way Home  JANUARY  508763
# 4        The Upside  JANUARY  440472

# %%
df_2019.drop(columns =["Opening"], inplace =True)

# %%
df_2019.rename(columns ={"Title" : "Original_title"}, inplace = True)

# %%
df_2019.head()
# Out:
#      Original_title      id
# 0       Escape Room  522681
# 1        Rust Creek  561362
# 2  American Hangman  567738
# 3  A Dog's Way Home  508763
# 4        The Upside  440472

# %% [markdown]
# ### Filmes de 2020

# %%
url_2020= "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

df1_2020 = pd.read_html(url_2020, header = 0)[2]
df2_2020 = pd.read_html(url_2020, header = 0)[3]
df3_2020 = pd.read_html(url_2020, header = 0)[4]
df4_2020 = pd.read_html(url_2020, header = 0)[5]

# %%
df_2020 = df1_2020.append(df2_2020.append(df3_2020.append(df4_2020, ignore_index=True), ignore_index=True), ignore_index=True)
df_2020.tail(6)
# Out:
#       Opening  Opening.1                  Title  \
# 268  DECEMBER         25                   Soul
# 269  DECEMBER         25       We Can Be Heroes
# 270  DECEMBER         25      News of the World
# 271  DECEMBER         25  One Night in Miami...
# 272  DECEMBER         25  Promising Young Woman
# 273  DECEMBER         30      Pieces of a Woman
#
#                                     Production company  \
# 268  Disney+ / Walt Disney Pictures / Pixar Animati...
# 269  Netflix / Troublemaker Studios / Double R Prod...
# 270        Universal Pictures / Perfect World Pictures
# 271                                     Amazon Studios
# 272          Focus Features / FilmNation Entertainment
# 273                             Netflix / Bron Studios
#
#                                          Cast and crew  \
# 268  Pete Docter (director/screenplay); Mike Jones,...
# 269  Robert Rodriguez (director/screenplay); Priyan...
# 270  Paul Greengrass (director/screenplay); Luke Da...
# 271  Regina King (director); Kemp Powers (screenpla...
# 272  Emerald Fennell (director/screenplay); Carey M...
# 273  Kornél Mundruczó (director); Kata Wéber (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
#
#       Ref.
# 268  [239]
# 269  [240]
# 270  [241]
# 271  [242]
# 272  [243]
# 273  [244]

# %%
df_2020 = df_2020.filter(["Title", "Opening"], axis = 1)

# %%
df_2020.head()
# Out:
#                Title  Opening
# 0         The Grudge  JANUARY
# 1         Underwater  JANUARY
# 2        Like a Boss  JANUARY
# 3      Three Christs  JANUARY
# 4  Inherit the Viper  JANUARY

# %%
df_2020["id"] = df_2020["Title"].map(lambda x : get_id_movie_2019(str(x)))

# %%
df_2020.drop(columns=["Opening"], inplace = True)

# %%
df_2020.head()
# Out:
#                Title      id
# 0         The Grudge    1970
# 1         Underwater  443791
# 2        Like a Boss  526019
# 3      Three Christs  418533
# 4  Inherit the Viper  634904

# %%
df_2020.rename(columns = {"Title" :"Original_title" }, inplace = True)

# %%
df_2020.head()
# Out:
#       Original_title      id
# 0         The Grudge    1970
# 1         Underwater  443791
# 2        Like a Boss  526019
# 3      Three Christs  418533
# 4  Inherit the Viper  634904

# %% [markdown]
# ### Filmes 2021

# %%
url_2021 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"

# %%
df1_2021 = pd.read_html(url_2021, header=0)[2]
df2_2021 = pd.read_html(url_2021, header=0)[3]
df3_2021 = pd.read_html(url_2021, header=0)[4]
df4_2021 = pd.read_html(url_2021, header=0)[5]

# %%
df1_2021
# Out:
#     Opening  Opening.1                Title  \
# 0   JANUARY          1  Shadow in the Cloud
# 1   JANUARY         13      The White Tiger
# 2   JANUARY         14          Locked Down
# 3   JANUARY         15              The Dig
# 4   JANUARY         15     Outside the Wire
# ..      ...        ...                  ...
# 61    MARCH         26               Nobody
# 62    MARCH         26             Bad Trip
# 63    MARCH         26      The Seventh Day
# 64    MARCH         26        Senior Moment
# 65    MARCH         31    Godzilla vs. Kong
#
#                                    Production company  \
# 0                              Vertical Entertainment
# 1                                             Netflix
# 2                     HBO Max / Warner Bros. Pictures
# 3                         Netflix / Clerkenwell Films
# 4                                             Netflix
# ..                                                ...
# 61  Universal Pictures / Perfect World Pictures / ...
# 62                           Netflix / Orion Pictures
# 63          Vertical Entertainment / Voltage Pictures
# 64                                 Screen Media Films
# 65  Warner Bros. Pictures / Legendary Entertainmen...
#
#                                         Cast and crew  \
# 0   Roseanne Liang (director/screenplay); Max Land...
# 1   Ramin Bahrani (director/screenplay); Adarsh Go...
# 2   Doug Liman (director); Steven Knight (screenpl...
# 3   Simon Stone (director); Moira Buffini (screenp...
# 4   Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                ...
# 61  Ilya Naishuller (director); Derek Kolstad (scr...
# 62  Kitao Sakurai (director/screenplay); Dan Curry...
# 63  Justin P. Lange (director/screenplay); Guy Pea...
# 64  Giorgio Serafini (director); Kurt Brungardt, C...
# 65  Adam Wingard (director); Eric Pearson, Max Bor...
#
#    .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.
# 0                                                 [2]
# 1                                                 NaN
# 2                                                 [3]
# 3                                                 [4]
# 4                                                 [5]
# ..                                                ...
# 61                                               [52]
# 62                                                NaN
# 63                                               [53]
# 64                                               [54]
# 65                                               [55]
#
# [66 rows x 6 columns]

# %%
df_2021 = df1_2021.append(df2_2021.append(df3_2021.append(df4_2021, ignore_index= True), ignore_index= True), ignore_index= True)

# %%
df_2021 = df_2021.filter(["Title", "Opening"], axis = 1)

# %%
df_2021.head()
# Out:
#                  Title  Opening
# 0  Shadow in the Cloud  JANUARY
# 1      The White Tiger  JANUARY
# 2          Locked Down  JANUARY
# 3              The Dig  JANUARY
# 4     Outside the Wire  JANUARY

# %%
df_2021["id"] = df_2021["Title"].map(lambda x : get_id_movie_2019(str(x)))

# %%
df_2021.head()
# Out:
#                  Title  Opening      id
# 0  Shadow in the Cloud  JANUARY  675327
# 1      The White Tiger  JANUARY  628534
# 2          Locked Down  JANUARY  741228
# 3              The Dig  JANUARY  532865
# 4     Outside the Wire  JANUARY  775996

# %%
df_2021.drop(columns=["Opening"], inplace= True)

# %%
df_2021.rename(columns={"Title" : "Original_title"}, inplace=True)

# %%
df_2021.head()
# Out:
#         Original_title      id
# 0  Shadow in the Cloud  675327
# 1      The White Tiger  628534
# 2          Locked Down  741228
# 3              The Dig  532865
# 4     Outside the Wire  775996

# %% [markdown]
# ###Filmes 2022

# %%
url_2022 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"

# %%
df1_2022 = pd.read_html(url_2022, header=0)[3]
df2_2022 = pd.read_html(url_2022, header=0)[4]
df3_2022 = pd.read_html(url_2022, header=0)[5]
df4_2022 = pd.read_html(url_2022, header=0)[6]

# %%
df1_2022.head()
# Out:
#    Opening  Opening.1                              Title  \
# 0  JANUARY          7                            The 355
# 1  JANUARY          7           The Legend of La Llorona
# 2  JANUARY          7                       The Commando
# 3  JANUARY         14                             Scream
# 4  JANUARY         14  Hotel Transylvania: Transformania
#
#                                   Production company  \
# 0  Universal Pictures / Freckle Films / FilmNatio...
# 1                                        Saban Films
# 2                                        Saban Films
# 3          Paramount Pictures / Spyglass Media Group
# 4  Amazon Studios / Columbia Pictures / Sony Pict...
#
#                                        Cast and crew  \
# 0  Simon Kinberg (director/screenplay); Theresa R...
# 1  Patricia Harris Seeley (director/screenplay); ...
# 2  Asif Akbar (director); Koji Steven Sakai (scre...
# 3  Matt Bettinelli-Olpin, Tyler Gillett (director...
# 4  Jennifer Kluska, Derek Drymon (directors); Amo...
#
#   .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.
# 0                                                [2]
# 1                                                [3]
# 2                                                [4]
# 3                                                [5]
# 4                                                [6]

# %%
df_2022 = df1_2022.append(df2_2022.append(df3_2022.append(df4_2022, ignore_index=True), ignore_index=True), ignore_index=True)

# %%
df_2022.head()
# Out:
#    Opening  Opening.1                              Title  \
# 0  JANUARY        7.0                            The 355
# 1  JANUARY        7.0           The Legend of La Llorona
# 2  JANUARY        7.0                       The Commando
# 3  JANUARY       14.0                             Scream
# 4  JANUARY       14.0  Hotel Transylvania: Transformania
#
#                                   Production company  \
# 0  Universal Pictures / Freckle Films / FilmNatio...
# 1                                        Saban Films
# 2                                        Saban Films
# 3          Paramount Pictures / Spyglass Media Group
# 4  Amazon Studios / Columbia Pictures / Sony Pict...
#
#                                        Cast and crew  \
# 0  Simon Kinberg (director/screenplay); Theresa R...
# 1  Patricia Harris Seeley (director/screenplay); ...
# 2  Asif Akbar (director); Koji Steven Sakai (scre...
# 3  Matt Bettinelli-Olpin, Tyler Gillett (director...
# 4  Jennifer Kluska, Derek Drymon (directors); Amo...
#
#   .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                [2]
# 1                                                [3]
# 2                                                [4]
# 3                                                [5]
# 4                                                [6]
#
#   Ref.
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
df_2022 = df_2022.filter(["Title" , "Opening"], axis=1 )

# %%
df_2022.head()
# Out:
#                                Title  Opening
# 0                            The 355  JANUARY
# 1           The Legend of La Llorona  JANUARY
# 2                       The Commando  JANUARY
# 3                             Scream  JANUARY
# 4  Hotel Transylvania: Transformania  JANUARY

# %%
df_2022["id"] = df_2022["Title"].map(lambda x : get_id_movie_2019(str(x)))

# %%
df_2022.tail()
# Out:
#                   Title   Opening      id
# 305             Babylon  DECEMBER  615777
# 306  They Cloned Tyrone  DECEMBER  736769
# 307                 NaN  DECEMBER   49642
# 308                 NaN  DECEMBER   49642
# 309                 NaN  DECEMBER   49642

# %%
df_2022.drop(columns=["Opening"], inplace= True)

# %%
df_2022.rename(columns={"Title" : "Original_title"}, inplace=True)

# %%
df_2022.head()
# Out:
#                       Original_title      id
# 0                            The 355  522016
# 1           The Legend of La Llorona  116322
# 2                       The Commando  753232
# 3                             Scream  646385
# 4  Hotel Transylvania: Transformania  585083

# %% [markdown]
# ## Concatenando

# %%
lista_dfs = [df_2018, df_2019, df_2020, df_2021, df_2022]

# %%
dfs_concat = pd.concat(lista_dfs, ignore_index = True)

# %%
dfs_concat.head(15)
# Out:
#                  Original_title      id
# 0       Insidious: The Last Key  406563
# 1              The Strange Ones  426258
# 2                      Stratton  348389
# 3                 Sweet Country  468210
# 4                  The Commuter  399035
# 5                    Proud Mary  442064
# 6              Acts of Violence  479040
# 7                    Freak Show  440424
# 8                      Humor Me  460216
# 9                       Vazante  436355
# 10  Mary and the Witch's Flower  430447
# 11                    12 Strong  429351
# 12               Den of Thieves  449443
# 13              Forever My Girl  417261
# 14  Maze Runner: The Death Cure  336843

# %% [markdown]
# ##Conjunto de dados Kaggle

# %%
df_movies = pd.read_csv("tmdb_5000_movies.csv")

# %%
df_movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
dfs_concat.head()
# Out:
#             Original_title      id
# 0  Insidious: The Last Key  406563
# 1         The Strange Ones  426258
# 2                 Stratton  348389
# 3            Sweet Country  468210
# 4             The Commuter  399035

# %%
response_teste = requests.get("https://api.themoviedb.org/3/movie/{}?api_key={}". format( 399035, tmdb.api_key ))

# %%
respnse_json = response_teste.json()

# %%
respnse_json
# Out:
# {'adult': False,
#  'backdrop_path': '/clmYuR1t4TtKcakIOvYIPrjyxDc.jpg',
#  'belongs_to_collection': None,
#  'budget': 30000000,
#  'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 53, 'name': 'Thriller'},
#   {'id': 9648, 'name': 'Mystery'}],
#  'homepage': 'https://thecommuter.movie/',
#  'id': 399035,
#  'imdb_id': 'tt1590193',
#  'original_language': 'en',
#  'original_title': 'The Commuter',
#  'overview': 'A businessman, on his daily commute home, gets unwittingly caught up in a criminal conspiracy that threatens not only his life but the lives of those around him.',
#  'popularity': 22.031,
#  'poster_path': '/rDeGK6FIUfVcXmuBdEORPAGPMNg.jpg',
#  'production_companies': [{'id': 104,
#    'logo_path': '/9aotxauvc9685tq9pTcRJszuT06.png',
#    'name': 'Canal+',
#    'origin_country': 'FR'},
#   {'id': 356,
#    'logo_path': '/tSJvuFaLIp7l0ONLUiAHA61GbXu.png',
#    'name': 'TF1 Films Production',
#    'origin_country': 'FR'},
#   {'id': 694,
#    'logo_path': '/5LEHONGkZBIoWvp1ygHOF8iyi1M.png',
#    'name': 'StudioCanal',
#    'origin_country': 'FR'},
#   {'id': 1632,
#    'logo_path': '/cisLn1YAUuptXVBa0xjq7ST9cH0.png',
#    'name': 'Lionsgate',
#    'origin_country': 'US'},
#   {'id': 10611,
#    'logo_path': '/zQ4fGaEnNkWfSzyygXRcUZwPmDG.png',
#    'name': 'Ciné+',
#    'origin_country': 'FR'},
#   {'id': 14714,
#    'logo_path': '/dSHaVKtBCpMU5VP9wMbTkqov62i.png',
#    'name': 'China Film Group Corporation',
#    'origin_country': 'CN'},
#   {'id': 19404,
#    'logo_path': None,
#    'name': 'Pinewood Studios',
#    'origin_country': 'GB'},
#   {'id': 23513,
#    'logo_path': None,
#    'name': 'Ombra Films',
#    'origin_country': 'US'},
#   {'id': 30148,
#    'logo_path': '/zerhOenUD6CkH8SMgZUhrDkOs4w.png',
#    'name': 'Bona Film Group',
#    'origin_country': 'CN'},
#   {'id': 99132,
#    'logo_path': None,
#    'name': 'The Picture Company',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'CA', 'name': 'Canada'},
#   {'iso_3166_1': 'CN', 'name': 'China'},
#   {'iso_3166_1': 'FR', 'name': 'France'},
#   {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#   {'iso_3166_1': 'US', 'name': 'United States of America'}],
#  'release_date': '2018-01-11',
#  'revenue': 119942387,
#  'runtime': 104,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Lives are on the line',
#  'title': 'The Commuter',
#  'video': False,
#  'vote_average': 6.324,
#  'vote_count': 3867}

# %%
def get_genres(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}?api_key={}". format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
   data_json = data_json["genres"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["genres"] = dfs_concat["id"].map(lambda x : get_genres(str(x)))

# %%
dfs_concat.head()
# Out:
#             Original_title      id  \
# 0  Insidious: The Last Key  406563
# 1         The Strange Ones  426258
# 2                 Stratton  348389
# 3            Sweet Country  468210
# 4             The Commuter  399035
#
#                                               genres
# 0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 1  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...

# %%
def get_budget(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}?api_key={}". format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json = data_json["budget"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["Budget"] = dfs_concat["id"].map(lambda x : get_budget(str(x)))

# %%
dfs_concat.rename(columns={"Budget" : "budget"}, inplace = True)

# %%
dfs_concat.head()
# Out:
#             Original_title      id  \
# 0  Insidious: The Last Key  406563
# 1         The Strange Ones  426258
# 2                 Stratton  348389
# 3            Sweet Country  468210
# 4             The Commuter  399035
#
#                                               genres    budget
# 0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...  10000000
# 1  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...         0
# 2  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...         0
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...         0
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  30000000

# %%
def get_homepage(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}?api_key={}". format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json = data_json["homepage"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["homepage"] = dfs_concat["id"].map(lambda x : get_homepage(str(x)))

# %%
dfs_concat.head()
# Out:
#             Original_title      id  \
# 0  Insidious: The Last Key  406563
# 1         The Strange Ones  426258
# 2                 Stratton  348389
# 3            Sweet Country  468210
# 4             The Commuter  399035
#
#                                               genres    budget  \
# 0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...  10000000
# 1  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...         0
# 2  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...         0
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...         0
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  30000000
#
#                                          homepage
# 0                   http://www.insidiousmovie.com
# 1                      http://thestrangeones.com/
# 2              http://www.gfmfilms.co.uk/stratton
# 3  https://bunyaproductions.com.au/sweet-country/
# 4                      https://thecommuter.movie/

# %%
def get_original_language(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}?api_key={}". format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json = data_json["original_language"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["original_language"] = dfs_concat["id"].map(lambda x : get_original_language(str(x)))

# %%
def get_overview(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}?api_key={}". format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json = data_json["overview"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["overview"] = dfs_concat["id"].map(lambda x : get_overview(str(x)))

# %%
def get_popularity(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}?api_key={}". format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json = data_json["popularity"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["popularity"] = dfs_concat["id"].map(lambda x : get_popularity(str(x)))

# %%
dfs_concat.head()
# Out:
#             Original_title      id  \
# 0  Insidious: The Last Key  406563
# 1         The Strange Ones  426258
# 2                 Stratton  348389
# 3            Sweet Country  468210
# 4             The Commuter  399035
#
#                                               genres    budget  \
# 0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...  10000000
# 1  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...         0
# 2  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...         0
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...         0
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  30000000
#
#                                          homepage original_language  \
# 0                   http://www.insidiousmovie.com                en
# 1                      http://thestrangeones.com/                en
# 2              http://www.gfmfilms.co.uk/stratton                en
# 3  https://bunyaproductions.com.au/sweet-country/                en
# 4                      https://thecommuter.movie/                en
#
#                                             overview popularity
# 0  Parapsychologist Elise Rainier and her team tr...     51.347
# 1  Mysterious events surround the travels of two ...      5.273
# 2  A British Special Boat Service commando tracks...     10.128
# 3  It’s 1929 on the vast, desert-like, Eastern Ar...       7.58
# 4  A businessman, on his daily commute home, gets...     22.031

# %%
def get_production_companies(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}?api_key={}". format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json = data_json["production_companies"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["production_companies"] = dfs_concat["id"].map(lambda x : get_production_companies(str(x)))

# %%
dfs_concat.head()
# Out:
#             Original_title      id  \
# 0  Insidious: The Last Key  406563
# 1         The Strange Ones  426258
# 2                 Stratton  348389
# 3            Sweet Country  468210
# 4             The Commuter  399035
#
#                                               genres    budget  \
# 0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...  10000000
# 1  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...         0
# 2  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...         0
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...         0
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  30000000
#
#                                          homepage original_language  \
# 0                   http://www.insidiousmovie.com                en
# 1                      http://thestrangeones.com/                en
# 2              http://www.gfmfilms.co.uk/stratton                en
# 3  https://bunyaproductions.com.au/sweet-country/                en
# 4                      https://thecommuter.movie/                en
#
#                                             overview popularity  \
# 0  Parapsychologist Elise Rainier and her team tr...     51.347
# 1  Mysterious events surround the travels of two ...      5.273
# 2  A British Special Boat Service commando tracks...     10.128
# 3  It’s 1929 on the vast, desert-like, Eastern Ar...       7.58
# 4  A businessman, on his daily commute home, gets...     22.031
#
#                                 production_companies
# 0  [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 1  [{'id': 35562, 'logo_path': '/cpeGUCuKo2vgaxzr...
# 2  [{'id': 23970, 'logo_path': None, 'name': 'Twi...
# 3  [{'id': 86737, 'logo_path': None, 'name': 'Bun...
# 4  [{'id': 104, 'logo_path': '/9aotxauvc9685tq9pT...

# %%
def get_production_countries(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}?api_key={}". format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json = data_json["production_countries"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["production_countries"] = dfs_concat["id"].map(lambda x : get_production_countries(str(x)))

# %%
def get_release_date(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}?api_key={}". format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json = data_json["release_date"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["release_date"] = dfs_concat["id"].map(lambda x : get_release_date(str(x)))

# %%
dfs_concat.head()
# Out:
#             Original_title      id  \
# 0  Insidious: The Last Key  406563
# 1         The Strange Ones  426258
# 2                 Stratton  348389
# 3            Sweet Country  468210
# 4             The Commuter  399035
#
#                                               genres    budget  \
# 0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...  10000000
# 1  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...         0
# 2  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...         0
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...         0
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  30000000
#
#                                          homepage original_language  \
# 0                   http://www.insidiousmovie.com                en
# 1                      http://thestrangeones.com/                en
# 2              http://www.gfmfilms.co.uk/stratton                en
# 3  https://bunyaproductions.com.au/sweet-country/                en
# 4                      https://thecommuter.movie/                en
#
#                                             overview popularity  \
# 0  Parapsychologist Elise Rainier and her team tr...     51.347
# 1  Mysterious events surround the travels of two ...      5.273
# 2  A British Special Boat Service commando tracks...     10.128
# 3  It’s 1929 on the vast, desert-like, Eastern Ar...       7.58
# 4  A businessman, on his daily commute home, gets...     22.031
#
#                                 production_companies  \
# 0  [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 1  [{'id': 35562, 'logo_path': '/cpeGUCuKo2vgaxzr...
# 2  [{'id': 23970, 'logo_path': None, 'name': 'Twi...
# 3  [{'id': 86737, 'logo_path': None, 'name': 'Bun...
# 4  [{'id': 104, 'logo_path': '/9aotxauvc9685tq9pT...
#
#                                 production_countries release_date
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2018-01-03
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2018-01-05
# 2   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-07-06
# 3        [{'iso_3166_1': 'AU', 'name': 'Australia'}]   2018-01-25
# 4  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   2018-01-11

# %%
def get_revenue(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}?api_key={}". format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json = data_json["revenue"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["revenue"] = dfs_concat["id"].map(lambda x : get_revenue(str(x)))

# %%
dfs_concat.head(1)
# Out:
#             original_title      id  \
# 0  Insidious: The Last Key  406563
#
#                                               genres    budget  \
# 0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...  10000000
#
#                         homepage original_language  \
# 0  http://www.insidiousmovie.com                en
#
#                                             overview popularity  \
# 0  Parapsychologist Elise Rainier and her team tr...     51.347
#
#                                 production_companies  \
# 0  [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
#
#                                 production_countries  ... runtime    status  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...  ...     103  Released
#
#             tagline                    title vote_average vote_count  \
# 0  Fear comes home.  Insidious: The Last Key        6.232       2316
#
#                                             keywords  \
# 0  [{'id': 2723, 'name': 'medium'}, {'id': 2849, ...
#
#                                     spoken_languages  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                                 cast  \
# 0  [{'adult': False, 'gender': 1, 'id': 7401, 'kn...
#
#                                                 crew
# 0  [{'adult': False, 'gender': 1, 'id': 494, 'kno...
#
# [1 rows x 22 columns]

# %%
def get_runtime(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}?api_key={}". format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json = data_json["runtime"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["runtime"] = dfs_concat["id"].map(lambda x : get_runtime(str(x)))

# %%
def get_status(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}?api_key={}". format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json = data_json["status"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["status"] = dfs_concat["id"].map(lambda x : get_status(str(x)))

# %%
def get_tagline(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}?api_key={}". format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json = data_json["tagline"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["tagline"] = dfs_concat["id"].map(lambda x : get_tagline(str(x)))

# %%
def get_title(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}?api_key={}". format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json = data_json["title"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["title"] = dfs_concat["id"].map(lambda x : get_title(str(x)))

# %%
def get_vote_average(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}?api_key={}". format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json = data_json["vote_average"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["vote_average"] = dfs_concat["id"].map(lambda x : get_vote_average(str(x)))

# %%
def get_vote_count(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}?api_key={}". format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json = data_json["vote_count"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["vote_count"] = dfs_concat["id"].map(lambda x : get_vote_count(str(x)))

# %%
dfs_concat.head()
# Out:
#             Original_title      id  \
# 0  Insidious: The Last Key  406563
# 1         The Strange Ones  426258
# 2                 Stratton  348389
# 3            Sweet Country  468210
# 4             The Commuter  399035
#
#                                               genres    budget  \
# 0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...  10000000
# 1  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...         0
# 2  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...         0
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...         0
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  30000000
#
#                                          homepage original_language  \
# 0                   http://www.insidiousmovie.com                en
# 1                      http://thestrangeones.com/                en
# 2              http://www.gfmfilms.co.uk/stratton                en
# 3  https://bunyaproductions.com.au/sweet-country/                en
# 4                      https://thecommuter.movie/                en
#
#                                             overview popularity  \
# 0  Parapsychologist Elise Rainier and her team tr...     51.347
# 1  Mysterious events surround the travels of two ...      5.273
# 2  A British Special Boat Service commando tracks...     10.128
# 3  It’s 1929 on the vast, desert-like, Eastern Ar...       7.58
# 4  A businessman, on his daily commute home, gets...     22.031
#
#                                 production_companies  \
# 0  [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 1  [{'id': 35562, 'logo_path': '/cpeGUCuKo2vgaxzr...
# 2  [{'id': 23970, 'logo_path': None, 'name': 'Twi...
# 3  [{'id': 86737, 'logo_path': None, 'name': 'Bun...
# 4  [{'id': 104, 'logo_path': '/9aotxauvc9685tq9pT...
#
#                                 production_countries release_date renuve  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2018-01-03    NAN
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2018-01-05    NAN
# 2   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-07-06    NAN
# 3        [{'iso_3166_1': 'AU', 'name': 'Australia'}]   2018-01-25    NAN
# 4  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   2018-01-11    NAN
#
#   runtime    status                            tagline  \
# 0     103  Released                   Fear comes home.
# 1      81  Released
# 2      94  Released  The enemy has a weapon. So do we.
# 3     113  Released     Justice itself is put on trial
# 4     104  Released              Lives are on the line
#
#                      title vote_average vote_count
# 0  Insidious: The Last Key        6.232       2316
# 1         The Strange Ones        5.508         62
# 2                 Stratton        4.984        183
# 3            Sweet Country        6.591        149
# 4             The Commuter        6.324       3867

# %%
def get_spoken_languages(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}?api_key={}". format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json = data_json["spoken_languages"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["spoken_languages"] = dfs_concat["id"].map(lambda x : get_spoken_languages(str(x)))

# %%
dfs_concat.rename(columns = {"renuve" : "revenue"}, inplace= True)

# %%
dfs_concat.rename(columns = {"Original_title" : "original_title"}, inplace= True)

# %% [markdown]
# ##Key WORDS

# %%
def get_keywords(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}/keywords?api_key={}". format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json = data_json["keywords"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["keywords"] = dfs_concat["id"].map(lambda x : get_keywords(str(x)))

# %%
dfs_concat.tail()
# Out:
#           Original_title      id  \
# 1452             Babylon  615777
# 1453  They Cloned Tyrone  736769
# 1454                 NaN   49642
# 1455                 NaN   49642
# 1456                 NaN   49642
#
#                                                  genres     budget  \
# 1452  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...  109000000
# 1453  [{'id': 878, 'name': 'Science Fiction'}, {'id'...          0
# 1454  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...          0
# 1455  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...          0
# 1456  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...          0
#
#                           homepage original_language  \
# 1452  https://www.babylonmovie.com                en
# 1453                                              en
# 1454                                              cn
# 1455                                              cn
# 1456                                              cn
#
#                                                overview popularity  \
# 1452  A tale of outsized ambition and outrageous exc...     16.206
# 1453  An unlikely trio investigates a series of eeri...      3.709
# 1454  A year after training young Jackie Chan in the...      6.347
# 1455  A year after training young Jackie Chan in the...      6.347
# 1456  A year after training young Jackie Chan in the...      6.347
#
#                                    production_companies  \
# 1452  [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
# 1453  [{'id': 79426, 'logo_path': '/8aEC7xem9YwHNCDo...
# 1454  [{'id': 13433, 'logo_path': '/kAHLkwogrcQJYcf0...
# 1455  [{'id': 13433, 'logo_path': '/kAHLkwogrcQJYcf0...
# 1456  [{'id': 13433, 'logo_path': '/kAHLkwogrcQJYcf0...
#
#                                    production_countries release_date revenue  \
# 1452  [{'iso_3166_1': 'US', 'name': 'United States o...   2022-12-25     NAN
# 1453                                                 []   2022-12-30     NAN
# 1454        [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   1979-06-26     NAN
# 1455        [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   1979-06-26     NAN
# 1456        [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   1979-06-26     NAN
#
#      runtime           status                          tagline  \
# 1452     183  Post Production             Always make a scene.
# 1453       0  Post Production  This conspiracy ain't a theory.
# 1454      94         Released
# 1455      94         Released
# 1456      94         Released
#
#                           title vote_average vote_count  \
# 1452                    Babylon          0.0          0
# 1453         They Cloned Tyrone          0.0          0
# 1454  Dance of the Drunk Mantis        7.307         44
# 1455  Dance of the Drunk Mantis        7.307         44
# 1456  Dance of the Drunk Mantis        7.307         44
#
#                                                keywords  \
# 1452  [{'id': 12396, 'name': 'hollywood'}, {'id': 20...
# 1453              [{'id': 10410, 'name': 'conspiracy'}]
# 1454  [{'id': 779, 'name': 'martial arts'}, {'id': 4...
# 1455  [{'id': 779, 'name': 'martial arts'}, {'id': 4...
# 1456  [{'id': 779, 'name': 'martial arts'}, {'id': 4...
#
#                                        spoken_languages
# 1452  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1453                                                 []
# 1454  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# 1455  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# 1456  [{'english_name': 'Cantonese', 'iso_639_1': 'c...

# %% [markdown]
# ### Comparando dataframe

# %%
df_movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
df_movies.shape
# Out:
# (4803, 20)

# %%
dfs_concat.columns
# Out:
# Index(['original_title', 'id', 'genres', 'budget', 'homepage',
#        'original_language', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime', 'status',
#        'tagline', 'title', 'vote_average', 'vote_count', 'keywords',
#        'spoken_languages', 'cast', 'crew'],
#       dtype='object')

# %%
dfs_concat.shape
# Out:
# (1457, 22)

# %% [markdown]
# ### Inserção dos creditos

# %%
dfs_concat.head()
# Out:
#             original_title      id  \
# 0  Insidious: The Last Key  406563
# 1         The Strange Ones  426258
# 2                 Stratton  348389
# 3            Sweet Country  468210
# 4             The Commuter  399035
#
#                                               genres    budget  \
# 0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...  10000000
# 1  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...         0
# 2  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...         0
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...         0
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  30000000
#
#                                          homepage original_language  \
# 0                   http://www.insidiousmovie.com                en
# 1                      http://thestrangeones.com/                en
# 2              http://www.gfmfilms.co.uk/stratton                en
# 3  https://bunyaproductions.com.au/sweet-country/                en
# 4                      https://thecommuter.movie/                en
#
#                                             overview popularity  \
# 0  Parapsychologist Elise Rainier and her team tr...     51.347
# 1  Mysterious events surround the travels of two ...      5.273
# 2  A British Special Boat Service commando tracks...     10.128
# 3  It’s 1929 on the vast, desert-like, Eastern Ar...       7.58
# 4  A businessman, on his daily commute home, gets...     22.031
#
#                                 production_companies  \
# 0  [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 1  [{'id': 35562, 'logo_path': '/cpeGUCuKo2vgaxzr...
# 2  [{'id': 23970, 'logo_path': None, 'name': 'Twi...
# 3  [{'id': 86737, 'logo_path': None, 'name': 'Bun...
# 4  [{'id': 104, 'logo_path': '/9aotxauvc9685tq9pT...
#
#                                 production_countries  ... runtime    status  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...  ...     103  Released
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...  ...      81  Released
# 2   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]  ...      94  Released
# 3        [{'iso_3166_1': 'AU', 'name': 'Australia'}]  ...     113  Released
# 4  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  ...     104  Released
#
#                              tagline                    title vote_average  \
# 0                   Fear comes home.  Insidious: The Last Key        6.232
# 1                                            The Strange Ones        5.508
# 2  The enemy has a weapon. So do we.                 Stratton        4.984
# 3     Justice itself is put on trial            Sweet Country        6.591
# 4              Lives are on the line             The Commuter        6.324
#
#   vote_count                                           keywords  \
# 0       2316  [{'id': 2723, 'name': 'medium'}, {'id': 2849, ...
# 1         62  [{'id': 380, 'name': 'sibling relationship'}, ...
# 2        183  [{'id': 818, 'name': 'based on novel or book'}...
# 3        149  [{'id': 570, 'name': 'rape'}, {'id': 2831, 'na...
# 4       3867  [{'id': 10410, 'name': 'conspiracy'}, {'id': 1...
#
#                                     spoken_languages  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                                 cast  \
# 0  [{'adult': False, 'gender': 1, 'id': 7401, 'kn...
# 1  [{'adult': False, 'gender': 2, 'id': 61363, 'k...
# 2  [{'adult': False, 'gender': 2, 'id': 55470, 'k...
# 3  [{'adult': False, 'gender': 2, 'id': 1887857, ...
# 4  [{'adult': False, 'gender': 2, 'id': 3896, 'kn...
#
#                                                 crew
# 0  [{'adult': False, 'gender': 1, 'id': 494, 'kno...
# 1  [{'adult': False, 'gender': 1, 'id': 17450, 'k...
# 2  [{'adult': False, 'gender': 1, 'id': 10496, 'k...
# 3  [{'adult': False, 'gender': 0, 'id': 55906, 'k...
# 4  [{'adult': False, 'gender': 2, 'id': 7230, 'kn...
#
# [5 rows x 22 columns]

# %%
df_movies_credits = pd.read_csv("tmdb_5000_credits.csv")

# %%
df_movies_credits.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
df_movies_credits.rename(columns= {"movie_id" : "id"}, inplace = True)

# %%
df_movies_credits.head(2)
# Out:
#       id                                     title  \
# 0  19995                                    Avatar
# 1    285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
df_movies_credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      4803 non-null   int64
#  1   title   4803 non-null   object
#  2   cast    4803 non-null   object
#  3   crew    4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %%
df_movies = df_movies.merge(df_movies_credits, on="id")

# %%
df_movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ...  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...
#
#       revenue runtime                                   spoken_languages  \
# 0  2787965087   162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
#
#      status                      tagline   title vote_average vote_count  \
# 0  Released  Enter the World of Pandora.  Avatar          7.2      11800
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
#
# [1 rows x 22 columns]

# %% [markdown]
# ##Filmes inseridos 2018 -2019 -2020 -2021- 2022

# %%
def get_credits_cast(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}/credits?api_key={}".format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json =  data_json["cast"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["cast"] = dfs_concat["id"].map(lambda x : get_credits_cast(str(x)))

# %%
dfs_concat.head()
# Out:
#             original_title      id  \
# 0  Insidious: The Last Key  406563
# 1         The Strange Ones  426258
# 2                 Stratton  348389
# 3            Sweet Country  468210
# 4             The Commuter  399035
#
#                                               genres    budget  \
# 0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...  10000000
# 1  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...         0
# 2  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...         0
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...         0
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  30000000
#
#                                          homepage original_language  \
# 0                   http://www.insidiousmovie.com                en
# 1                      http://thestrangeones.com/                en
# 2              http://www.gfmfilms.co.uk/stratton                en
# 3  https://bunyaproductions.com.au/sweet-country/                en
# 4                      https://thecommuter.movie/                en
#
#                                             overview popularity  \
# 0  Parapsychologist Elise Rainier and her team tr...     51.347
# 1  Mysterious events surround the travels of two ...      5.273
# 2  A British Special Boat Service commando tracks...     10.128
# 3  It’s 1929 on the vast, desert-like, Eastern Ar...       7.58
# 4  A businessman, on his daily commute home, gets...     22.031
#
#                                 production_companies  \
# 0  [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 1  [{'id': 35562, 'logo_path': '/cpeGUCuKo2vgaxzr...
# 2  [{'id': 23970, 'logo_path': None, 'name': 'Twi...
# 3  [{'id': 86737, 'logo_path': None, 'name': 'Bun...
# 4  [{'id': 104, 'logo_path': '/9aotxauvc9685tq9pT...
#
#                                 production_countries  ... revenue runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...  ...     NAN     103
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...  ...     NAN      81
# 2   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]  ...     NAN      94
# 3        [{'iso_3166_1': 'AU', 'name': 'Australia'}]  ...     NAN     113
# 4  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  ...     NAN     104
#
#      status                            tagline                    title  \
# 0  Released                   Fear comes home.  Insidious: The Last Key
# 1  Released                                            The Strange Ones
# 2  Released  The enemy has a weapon. So do we.                 Stratton
# 3  Released     Justice itself is put on trial            Sweet Country
# 4  Released              Lives are on the line             The Commuter
#
#   vote_average vote_count                                           keywords  \
# 0        6.232       2316  [{'id': 2723, 'name': 'medium'}, {'id': 2849, ...
# 1        5.508         62  [{'id': 380, 'name': 'sibling relationship'}, ...
# 2        4.984        183  [{'id': 818, 'name': 'based on novel or book'}...
# 3        6.591        149  [{'id': 570, 'name': 'rape'}, {'id': 2831, 'na...
# 4        6.324       3867  [{'id': 10410, 'name': 'conspiracy'}, {'id': 1...
#
#                                     spoken_languages  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                                 cast
# 0  [{'adult': False, 'gender': 1, 'id': 7401, 'kn...
# 1  [{'adult': False, 'gender': 2, 'id': 61363, 'k...
# 2  [{'adult': False, 'gender': 2, 'id': 55470, 'k...
# 3  [{'adult': False, 'gender': 2, 'id': 1887857, ...
# 4  [{'adult': False, 'gender': 2, 'id': 3896, 'kn...
#
# [5 rows x 21 columns]

# %%
def get_credits_crew(movie_id):
  response = requests.get("https://api.themoviedb.org/3/movie/{}/credits?api_key={}".format(movie_id, tmdb.api_key ))
  data_json = json.loads(response.text)
  try:
    data_json =  data_json["crew"]
  except:
   data_json = "NAN"
  return data_json

# %%
dfs_concat["crew"] = dfs_concat["id"].map(lambda x : get_credits_crew(str(x)))

# %%
dfs_concat.head()
# Out:
#             original_title      id  \
# 0  Insidious: The Last Key  406563
# 1         The Strange Ones  426258
# 2                 Stratton  348389
# 3            Sweet Country  468210
# 4             The Commuter  399035
#
#                                               genres    budget  \
# 0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...  10000000
# 1  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...         0
# 2  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...         0
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...         0
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  30000000
#
#                                          homepage original_language  \
# 0                   http://www.insidiousmovie.com                en
# 1                      http://thestrangeones.com/                en
# 2              http://www.gfmfilms.co.uk/stratton                en
# 3  https://bunyaproductions.com.au/sweet-country/                en
# 4                      https://thecommuter.movie/                en
#
#                                             overview popularity  \
# 0  Parapsychologist Elise Rainier and her team tr...     51.347
# 1  Mysterious events surround the travels of two ...      5.273
# 2  A British Special Boat Service commando tracks...     10.128
# 3  It’s 1929 on the vast, desert-like, Eastern Ar...       7.58
# 4  A businessman, on his daily commute home, gets...     22.031
#
#                                 production_companies  \
# 0  [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 1  [{'id': 35562, 'logo_path': '/cpeGUCuKo2vgaxzr...
# 2  [{'id': 23970, 'logo_path': None, 'name': 'Twi...
# 3  [{'id': 86737, 'logo_path': None, 'name': 'Bun...
# 4  [{'id': 104, 'logo_path': '/9aotxauvc9685tq9pT...
#
#                                 production_countries  ... runtime    status  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...  ...     103  Released
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...  ...      81  Released
# 2   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]  ...      94  Released
# 3        [{'iso_3166_1': 'AU', 'name': 'Australia'}]  ...     113  Released
# 4  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  ...     104  Released
#
#                              tagline                    title vote_average  \
# 0                   Fear comes home.  Insidious: The Last Key        6.232
# 1                                            The Strange Ones        5.508
# 2  The enemy has a weapon. So do we.                 Stratton        4.984
# 3     Justice itself is put on trial            Sweet Country        6.591
# 4              Lives are on the line             The Commuter        6.324
#
#   vote_count                                           keywords  \
# 0       2316  [{'id': 2723, 'name': 'medium'}, {'id': 2849, ...
# 1         62  [{'id': 380, 'name': 'sibling relationship'}, ...
# 2        183  [{'id': 818, 'name': 'based on novel or book'}...
# 3        149  [{'id': 570, 'name': 'rape'}, {'id': 2831, 'na...
# 4       3867  [{'id': 10410, 'name': 'conspiracy'}, {'id': 1...
#
#                                     spoken_languages  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                                 cast  \
# 0  [{'adult': False, 'gender': 1, 'id': 7401, 'kn...
# 1  [{'adult': False, 'gender': 2, 'id': 61363, 'k...
# 2  [{'adult': False, 'gender': 2, 'id': 55470, 'k...
# 3  [{'adult': False, 'gender': 2, 'id': 1887857, ...
# 4  [{'adult': False, 'gender': 2, 'id': 3896, 'kn...
#
#                                                 crew
# 0  [{'adult': False, 'gender': 1, 'id': 494, 'kno...
# 1  [{'adult': False, 'gender': 1, 'id': 17450, 'k...
# 2  [{'adult': False, 'gender': 1, 'id': 10496, 'k...
# 3  [{'adult': False, 'gender': 0, 'id': 55906, 'k...
# 4  [{'adult': False, 'gender': 2, 'id': 7230, 'kn...
#
# [5 rows x 22 columns]

# %% [markdown]
# ###Concatatenação Final

# %%
df_movies.drop(["title_y"], axis = 1, inplace = True)

# %%
df_movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ...  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...
#
#       revenue runtime                                   spoken_languages  \
# 0  2787965087   162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
#
#      status                      tagline title_x vote_average vote_count  \
# 0  Released  Enter the World of Pandora.  Avatar          7.2      11800
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
#
# [1 rows x 22 columns]

# %%
df_movies.rename(columns = {"title_x" : "title" }, inplace =True)

# %%
df_movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ...     revenue runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...  2787965087   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   961000000   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   880674609   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...  1084939099   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   284139100   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
# 2                                   Spectre          6.3       4466
# 3                     The Dark Knight Rises          7.6       9106
# 4                               John Carter          6.1       2124
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 22 columns]

# %%
dataframe =[df_movies, dfs_concat]

# %%
df_final = pd.concat(dataframe, ignore_index =True)

# %%
df_final.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...   112.31295
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ...     revenue runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...  2787965087   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   961000000   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   880674609   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...  1084939099   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   284139100   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
# 2                                   Spectre          6.3       4466
# 3                     The Dark Knight Rises          7.6       9106
# 4                               John Carter          6.1       2124
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 22 columns]

# %%
df_movies.shape

# %%
dfs_concat.shape

# %%
df_final.shape

# %%
df_final.to_csv(r'/content/df_final.csv', index= False, header =True)

# %%
tt=df_final.columns
